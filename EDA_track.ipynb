# %% [markdown]
# ## General info
# The file is about 30% of file tf_000000000000.csv by using shuffle.
#
# The number of rows in tf_000000000000.csv is 1853312 totally.
#
# command line(MAC):
# gshuf -n 1500000 tf_000000000000.csv > sample.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
col = ['track_id','duration','release_year','us_popularity_estimate','acousticness','beat_strength','bounciness',
          'danceability','dyn_range_mean','energy','flatness','instrumentalness','key','liveness','loudness',
          'mechanism','mode','organism','speechiness','tempo','time_signature','valence','acoustic_vector_0',
          'acoustic_vector_1','acoustic_vector_2','acoustic_vector_3','acoustic_vector_4','acoustic_vector_5',
          'acoustic_vector_6','acoustic_vector_7']

# %%
df = pd.read_csv('sample.csv',header=0)
df.columns = col

# %%
#df.to_csv('samplewithname.csv')

# %%
df.head()
# Out:
#                                  track_id    duration  release_year  \
# 0  t_153b067b-8efa-4a42-868b-2cdaafab8819  354.893341          2013
# 1  t_4d7ff2bb-1243-4461-822a-10874a4f01be  309.000000          2017
# 2  t_09a75518-c81a-4558-b0bc-c4534a9d40d4  785.039978          2009
# 3  t_534690f3-637e-4108-ae66-6ad7aea00e9a  253.492233          2015
# 4  t_36187fa0-37e9-43ad-a44f-d43e15f75a10  183.243225          2017
#
#    us_popularity_estimate  acousticness  beat_strength  bounciness  \
# 0               95.694981      0.155154       0.834120    0.882338
# 1               99.904868      0.216396       0.493704    0.516818
# 2               92.416309      0.021062       0.418060    0.451649
# 3               97.879006      0.175067       0.520710    0.571764
# 4               97.463249      0.001957       0.418475    0.362614
#
#    danceability  dyn_range_mean    energy        ...          time_signature  \
# 0      0.879620       14.549646  0.348864        ...                       4
# 1      0.730393        7.972743  0.670536        ...                       4
# 2      0.438391        7.447088  0.761879        ...                       4
# 3      0.646579        8.779946  0.676720        ...                       4
# 4      0.609068        5.819139  0.837901        ...                       4
#
#     valence  acoustic_vector_0  acoustic_vector_1  acoustic_vector_2  \
# 0  0.648282          -0.809704           0.177370           0.173277
# 1  0.383536          -0.342510           0.284803           0.119678
# 2  0.381597           0.130152          -0.147168          -0.051233
# 3  0.807866          -0.197974           0.151337           0.286386
# 4  0.763639           0.035355           0.296591           0.140860
#
#    acoustic_vector_3 acoustic_vector_4  acoustic_vector_5  acoustic_vector_6  \
# 0           0.213941         -0.297045          -0.106267          -0.510054
# 1          -0.072233         -0.153990           0.113454          -0.087927
# 2          -0.057925          0.540076           0.019645          -0.267601
# 3          -0.147414         -0.702274           0.277201           0.284276
# 4          -0.417328          0.366034           0.188209          -0.452933
#
#    acoustic_vector_7
# 0           0.144168
# 1           0.159242
# 2          -0.163611
# 3           0.668219
# 4          -0.473342
#
# [5 rows x 30 columns]

# %%
df.describe()
# Out:
#             duration   release_year  us_popularity_estimate   acousticness  \
# count  549999.000000  549999.000000           549999.000000  549999.000000
# mean      233.215410    2009.245184               95.573843       0.347336
# std       109.026367      11.058930                2.738245       0.342855
# min        30.010071    1950.000000               90.000027       0.000000
# 25%       176.693329    2006.000000               93.381663       0.026669
# 50%       217.853333    2013.000000               95.759123       0.220614
# 75%       266.972473    2017.000000               97.924284       0.653900
# max      1799.813354    2018.000000               99.999982       0.995796
#
#        beat_strength     bounciness   danceability  dyn_range_mean  \
# count  549999.000000  549999.000000  549999.000000   549999.000000
# mean        0.461740       0.479149       0.556453        7.849124
# std         0.171894       0.199138       0.185902        2.678862
# min         0.000000       0.000000       0.000000        0.000000
# 25%         0.331558       0.320427       0.432619        5.821731
# 50%         0.459140       0.479538       0.572210        7.520566
# 75%         0.585525       0.634158       0.697409        9.480828
# max         0.997500       0.985092       0.997807       48.347000
#
#               energy       flatness        ...          time_signature  \
# count  549999.000000  549999.000000        ...           549999.000000
# mean        0.591465       0.993414        ...                3.874076
# std         0.260248       0.055349        ...                0.485782
# min         0.000000       0.000000        ...                0.000000
# 25%         0.409529       0.969170        ...                4.000000
# 50%         0.625463       1.002446        ...                4.000000
# 75%         0.806782       1.029159        ...                4.000000
# max         0.999982       1.167801        ...                5.000000
#
#              valence  acoustic_vector_0  acoustic_vector_1  acoustic_vector_2  \
# count  549999.000000      549999.000000      549999.000000      549999.000000
# mean        0.481247          -0.103795           0.014905           0.059279
# std         0.272777           0.432191           0.361267           0.280528
# min         0.000000          -1.127737          -1.170228          -0.885870
# 25%         0.251209          -0.408027          -0.177383          -0.147846
# 50%         0.472704          -0.039809           0.084359           0.128510
# 75%         0.705602           0.192504           0.283251           0.274886
# max         0.999990           0.992450           0.820775           0.637068
#
#        acoustic_vector_3  acoustic_vector_4  acoustic_vector_5  \
# count      549999.000000      549999.000000      549999.000000
# mean            0.053820           0.023241           0.000236
# std             0.382469           0.410870           0.212176
# min            -0.899445          -1.081056          -1.055477
# 25%            -0.235167          -0.311992          -0.091140
# 50%             0.062909          -0.015646           0.042502
# 75%             0.284745           0.372961           0.147532
# max             1.168534           0.953023           0.413015
#
#        acoustic_vector_6  acoustic_vector_7
# count      549999.000000      549999.000000
# mean           -0.024445          -0.001851
# std             0.374434           0.387675
# min            -0.773848          -1.044676
# 25%            -0.315394          -0.271058
# 50%            -0.098298          -0.004500
# 75%             0.206572           0.221651
# max             1.070549           1.185982
#
# [8 rows x 28 columns]

# %%
df.describe(include=['O'])
# Out:
#                                       track_id    mode
# count                                   549999  549999
# unique                                  549999       2
# top     t_68f3906a-7b47-4bac-9c6d-9e7ee4cd8921   major
# freq                                         1  357977

# %%
df.dtypes
# Out:
# track_id                   object
# duration                  float64
# release_year                int64
# us_popularity_estimate    float64
# acousticness              float64
# beat_strength             float64
# bounciness                float64
# danceability              float64
# dyn_range_mean            float64
# energy                    float64
# flatness                  float64
# instrumentalness          float64
# key                         int64
# liveness                  float64
# loudness                  float64
# mechanism                 float64
# mode                       object
# organism                  float64
# speechiness               float64
# tempo                     float64
# time_signature              int64
# valence                   float64
# acoustic_vector_0         float64
# acoustic_vector_1         float64
# acoustic_vector_2         float64
# acoustic_vector_3         float64
# acoustic_vector_4         float64
# acoustic_vector_5         float64
# acoustic_vector_6         float64
# acoustic_vector_7         float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# track_id                  0
# duration                  0
# release_year              0
# us_popularity_estimate    0
# acousticness              0
# beat_strength             0
# bounciness                0
# danceability              0
# dyn_range_mean            0
# energy                    0
# flatness                  0
# instrumentalness          0
# key                       0
# liveness                  0
# loudness                  0
# mechanism                 0
# mode                      0
# organism                  0
# speechiness               0
# tempo                     0
# time_signature            0
# valence                   0
# acoustic_vector_0         0
# acoustic_vector_1         0
# acoustic_vector_2         0
# acoustic_vector_3         0
# acoustic_vector_4         0
# acoustic_vector_5         0
# acoustic_vector_6         0
# acoustic_vector_7         0
# dtype: int64

# %% [markdown]
# ## release_year

# %%
plt.figure(figsize=(18,6))
df['release_year'].hist(bins=50)
plt.show()

# %%
df['release_year'].value_counts().head(20)
# Out:
# 2018    73230
# 2017    70401
# 2016    51107
# 2015    40904
# 2014    33865
# 2013    28349
# 2012    25088
# 2011    22087
# 2010    19302
# 2009    16663
# 2008    14842
# 2007    13100
# 2006    12875
# 2005    11652
# 2004     9329
# 2003     8785
# 2002     7755
# 2001     7183
# 2000     6883
# 1999     6370
# Name: release_year, dtype: int64

# %% [markdown]
# ## duration

# %%
plt.figure(figsize=(18,6))
df['duration'].hist(bins=50)
plt.show()

# %% [markdown]
# ## us_popularity_estimate

# %%
plt.figure(figsize=(18,6))
df['us_popularity_estimate'].hist(bins=50)
plt.show()

# %% [markdown]
# ## acousticness

# %%
col = ['duration','release_year','us_popularity_estimate',
       'acousticness','beat_strength','bounciness',
       'danceability','dyn_range_mean','energy',
       'flatness','instrumentalness','key','liveness',
       'loudness','mechanism','mode','organism',
       'speechiness','tempo','time_signature',
       'valence','acoustic_vector_0','acoustic_vector_1',
       'acoustic_vector_2','acoustic_vector_3','acoustic_vector_4',
       'acoustic_vector_5','acoustic_vector_6','acoustic_vector_7']

# %%
len(col)
# Out:
# 29

# %%
plt.figure(figsize=(30,20))
n = 1

for i in range(16,len(col)):
    plt.subplot(5,5,n)
    df[col[i]].hist()
    plt.xlabel(col[i])
    n +=1

# %%
1

# %% [markdown]
# ## acoustic_vector 0-8

# %%
plt.figure(figsize=(20,30))
n = 1

for colname in ['acoustic_vector_0','acoustic_vector_1','acoustic_vector_2',
                'acoustic_vector_3','acoustic_vector_4','acoustic_vector_5',
                'acoustic_vector_6','acoustic_vector_7']:
    plt.subplot(6,3,n)
    df[colname].hist()
    plt.xlabel(colname)
    n +=1

# %% [markdown]
# ## mode

# %%
df['mode'].unique()
# Out:
# array(['major', 'minor'], dtype=object)

# %%
df['mode'].value_counts()
# Out:
# major    357977
# minor    192022
# Name: mode, dtype: int64

# %% [markdown]
# ## correlation

# %%
corrmat=df.corr()
f, ax = plt.subplots(figsize=(30, 20))
sns.heatmap(corrmat,cbar=True, annot=True, vmax=.8, square=True, fmt='.2f', annot_kws={'size': 10});
